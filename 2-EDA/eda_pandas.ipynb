# %%
import pandas as pd

# %% [markdown]
# ### 1) Les series

# %%
# création d'une série :
data1 = pd.Series([1.2, 2.1, 3.4, 4.7], name = "values" )

# %%
pd.Series?

# %%
print(data1)
# Out:
# 0    1.2
# 1    2.1
# 2    3.4
# 3    4.7
# Name: values, dtype: float64

# %%
# récupérer l'objet index
data1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Affichage des index de l'objet index :
for index in data1.index:
  print(index)
# Out:
# 0
# 1
# 2
# 3

# %%
# récupérer une donnée à un index :
data1[2]
# Out:
# 3.4

# %%
# afficher les éléments de la série :
for element in data1 :
  print(element)
# Out:
# 1.2
# 2.1
# 3.4
# 4.7

# %%
# afficher la moyenne :
data1.mean()
# Out:
# 2.8499999999999996

# %% [markdown]
# ### 2) Les DataFrame

# %%
# initialiser un df avec un dictionnaire :
# contrainte : toutes les listes doivent avoir la même taille sinon ça ne marche pas.
data_dict = {
    'name': ['Agnes', 'Sidi', 'Thibault', 'Samia', 'Henry', 'Georges'],
    'age': [28, 37, 43, 33, 29, 57],
    'job': ['web analyst', 'sales director', 'web analyst', 'sales director',
                   'web analyst', 'developer']
            }

data2 = pd.DataFrame(data_dict)
display(data2) # Equivalent to print() with HTML rendering
# Out:
#        name  age             job
# 0     Agnes   28     web analyst
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 4     Henry   29     web analyst
# 5   Georges   57       developer

# %%
print(data2)
# Out:
#        name  age             job
# 0     Agnes   28     web analyst
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 4     Henry   29     web analyst
# 5   Georges   57       developer

# %%
# afficher index
data2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# afficher colonnes
data2.columns
# Out:
# Index(['name', 'age', 'job'], dtype='object')

# %%
# voir le nombre de lignes et colonnes
data2.shape
# Out:
# (6, 3)

# %%
# convertir le dataframe en un numpy array
data2.values
# Out:
# array([['Agnes', 28, 'web analyst'],
#        ['Sidi', 37, 'sales director'],
#        ['Thibault', 43, 'web analyst'],
#        ['Samia', 33, 'sales director'],
#        ['Henry', 29, 'web analyst'],
#        ['Georges', 57, 'developer']], dtype=object)

# %%
# 5 premières lignes
data2.head()
# Out:
#        name  age             job
# 0     Agnes   28     web analyst
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 4     Henry   29     web analyst

# %%
# 5 dernières lignes
data2.tail()
# Out:
#        name  age             job
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 4     Henry   29     web analyst
# 5   Georges   57       developer

# %%
# sélectionner une colonne
test = data2['name']
# type(test)
print(test)
# Out:
# 0       Agnes
# 1        Sidi
# 2    Thibault
# 3       Samia
# 4       Henry
# 5     Georges
# Name: name, dtype: object

# %%
# récupérer plusieurs colonnes
data2[['name', 'job']]
# Out:
#        name             job
# 0     Agnes     web analyst
# 1      Sidi  sales director
# 2  Thibault     web analyst
# 3     Samia  sales director
# 4     Henry     web analyst
# 5   Georges       developer

# %%
# selectionner des données avec des slices
display(data2.loc[0:2, :])  # [slices_lignes, slices_colonnes] Différence avec python : la valeur de l'index de fin de slice est inclus
# Out:
#        name  age             job
# 0     Agnes   28     web analyst
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst

# %%
# plusieurs colonnes
display(data2.loc[0:2, ['name', 'job']])
# Out:
#        name             job
# 0     Agnes     web analyst
# 1      Sidi  sales director
# 2  Thibault     web analyst

# %%
# use iloc pour récupérer des index négatifs ATTENTION : ne fonctionne qu'avec iloc pas avec loc
display(data2.iloc[:,-1])
# Out:
# 0       web analyst
# 1    sales director
# 2       web analyst
# 3    sales director
# 4       web analyst
# 5         developer
# Name: job, dtype: object

# %%
# utiliser des masks pour sélectionner des lignes qui répondent à une condition
# un masque équivaut à une clause WHERE en SQL il ne filtre que les lignes, pas les colonnes
mask = data2['age'] > 30  # le tri sera fait sur la colonne age. On ne demande que les >30
display(data2.loc[mask, :]) # on récupère les lignes filtrées par mask et ici toutes les colonnes
# Out:
#        name  age             job
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 5   Georges   57       developer

# %%
# dans le masque, on retrouve des booléens en fonction de notre condition
display(mask)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# Name: age, dtype: bool

# %%
# double test
mask = (data2['age'] > 30) & (data2['job'] == 'sales director')  # ATTENTION ! En pandas on utilise & ou | alors qu'en python on utilise and et or
display(data2.loc[mask, :])
# Out:
#     name  age             job
# 1   Sidi   37  sales director
# 3  Samia   33  sales director

# %%
a = True
b = False

# En python il compare des booléens et non pas des séries de booléens
a and b # ne renvoie True que si les deux sont à True.

a or b # si un des deux est à True

# En pandas, on compare des séries en utilisant & et |
# Out:
# True

# %%
# lire un fichier csv
data = pd.read_csv('source/chipotle.csv', index_col = 0)
display(data)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# afficher l'aide sur la méthode pd.read_csv
pd.read_csv?

# %%
# exporter un fichier en csv
data = pd.DataFrame({"first_name":["Lucien", "Jocelyne", "Brigitte"], "age":[29, 43, 32]})
data.to_csv("data.csv")

# %% [markdown]
# ### 3) Manipulation de données

# %%
display(data2)
# Out:
#        name  age             job
# 0     Agnes   28     web analyst
# 1      Sidi   37  sales director
# 2  Thibault   43     web analyst
# 3     Samia   33  sales director
# 4     Henry   29     web analyst
# 5   Georges   57       developer

# %%
# statistiques générales sur les données
data2.describe(include = 'all')  # all : pour avoir toutes les colonnes
# Out:
#          name        age          job
# count       6   6.000000            6
# unique      6        NaN            3
# top     Agnes        NaN  web analyst
# freq        1        NaN            3
# mean      NaN  37.833333          NaN
# std       NaN  10.888832          NaN
# min       NaN  28.000000          NaN
# 25%       NaN  30.000000          NaN
# 50%       NaN  35.000000          NaN
# 75%       NaN  41.500000          NaN
# max       NaN  57.000000          NaN

# %%
# ajouter une colonne avec des valeurs
data2['gender'] = ['F', 'M', 'M', 'F', 'M', 'M']
display(data2)
# Out:
#        name  age             job gender
# 0     Agnes   28     web analyst      F
# 1      Sidi   37  sales director      M
# 2  Thibault   43     web analyst      M
# 3     Samia   33  sales director      F
# 4     Henry   29     web analyst      M
# 5   Georges   57       developer      M

# %%
# ajouter des lignes à la suite de mon df
new_row = {
    'name': 'Joséphine',
    'age': 43,
    'job': 'developer',
    'gender': 'F'
          }

data2 = data2.append(new_row, ignore_index=True)  # ATTENTION append va être déprécié il faudra plus tard utiliser pd.concat() mais ok pour l'instant

display(data2)
# Out:
# <ipython-input-46-9c056ea84bf1>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_row, ignore_index=True)  # ATTENTION append va être déprécié il faut utiliser pd.concat()
#         name  age             job gender
# 0      Agnes   28     web analyst      F
# 1       Sidi   37  sales director      M
# 2   Thibault   43     web analyst      M
# 3      Samia   33  sales director      F
# 4      Henry   29     web analyst      M
# 5    Georges   57       developer      M
# 6  Joséphine   43       developer      F
# 7  Joséphine   43       developer      F
# 8  Joséphine   43       developer      F

# %%
# ajouter une colonne avec les résultats d'un calcul effectué sur d'autres colonnes

# New column containing the square of the age
data2['age_squared'] = data2['age'].apply(lambda x : x**2)

# New column containing: age if age > 30, 0 otherwise
data2['age_changed'] = data2['age'].apply(lambda x : x if x > 30 else 0)

# New column indicating that the person is NOT a web analyst
data2['not_web_analyst'] = data2['job'].apply(lambda x : x != 'web analyst')

display(data2)

# apply peut être utilisé aussi pour appliquer une fonction classique mais on utilise
# une lambda quand l'opération est très simple à réaliser et ne nécessite pas une fonction classique
# Out:
#         name  age             job gender  age_squared  age_changed  \
# 0      Agnes   28     web analyst      F          784            0
# 1       Sidi   37  sales director      M         1369           37
# 2   Thibault   43     web analyst      M         1849           43
# 3      Samia   33  sales director      F         1089           33
# 4      Henry   29     web analyst      M          841            0
# 5    Georges   57       developer      M         3249           57
# 6  Joséphine   43       developer      F         1849           43
# 7  Joséphine   43       developer      F         1849           43
# 8  Joséphine   43       developer      F         1849           43
#
#    not_web_analyst
# 0            False
# 1             True
# 2            False
# 3             True
# 4            False
# 5             True
# 6             True
# 7             True
# 8             True

# %% [markdown]
# REMARQUE : dans pandas, les données ne sont pas écrasées si on ne spécifie pas inplace = True

# %%
# aggregate des lignes avec groupby (pour faire une analyse segmentée, par exemple)

# Group by 'job' and then calculate the average value of the other columns
display(data2.groupby('job').mean())

# Group by 'job' then calculate the average value of the 'age' column.
display(data2.groupby('job')['age'].mean())

# Group by 'job' then 'gender' and calculate the median value of the other columns.
display(data2.groupby(['job', 'gender']).median())
# Out:
# <ipython-input-54-f19a9ed2d772>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   display(data2.groupby('job').mean())
#                       age  age_squared  age_changed  not_web_analyst
# job
# developer       46.500000       2199.0    46.500000              1.0
# sales director  35.000000       1229.0    35.000000              1.0
# web analyst     33.333333       1158.0    14.333333              0.0
# job
# developer         46.500000
# sales director    35.000000
# web analyst       33.333333
# Name: age, dtype: float64
# ...

# %%
# table pivot (équivalent à un tableau croisé dynamique dans Excel)

# DataFrame with :
# - as many rows as there are 'jobs'
# - as many columns as there is gender
# - the values are the average of 'age'
display(data2.pivot_table(index='job', columns='gender', values='age', aggfunc='mean'))
# index = ici je veux autant de lignes qu'il y a de valeurs différentes dans job
# columns = autant de colonnes qu'il y a de valeurs possibles dans gender
# values = où aller chercher les valeurs à utiliser (on peut passer plusieurs noms de colonnes)
# aggfunc = quelle opération faire pour calculer un résultat agrégé (min, max, mean, median...)
# Out:
# gender           F   M
# job
# developer       43  57
# sales director  33  37
# web analyst     28  36

# %%
# combiner des bdd

# Next, we will manipulate the following databases:
data_sales1 = {
    'sales_id' : ['001','002','003','004'],
    'people_id' : [1, 4, 2, 1],
    'product_id' : ['X789', 'X999', 'X789', 'X990']
              }

data_sales2 = {
    'sales_id' : ['005', '006', '007'],
    'people_id' : [0, 3, 2],
    'product_id' : ['X789', 'X999', 'X789']
               }

data_products = {
    'product_id' : ['X789', 'X999', 'X990'],
    'product_desc' : ['Apple', 'Banana', 'Orange']
                }

data_people = {
    'id' : [0, 1, 2, 3, 5],
    'name' : ['Paul','Perrine','Moussa','Michel', 'Anne'],
    'age' : [None, 67, 24, 76, 47]
              }

df_sales1 = pd.DataFrame(data_sales1)
df_sales2 = pd.DataFrame(data_sales2)
df_products = pd.DataFrame(data_products)
df_people = pd.DataFrame(data_people)

display(df_sales1)
display(df_sales2)
display(df_products)
display(df_people)
# Out:
#   sales_id  people_id product_id
# 0      001          1       X789
# 1      002          4       X999
# 2      003          2       X789
# 3      004          1       X990
#   sales_id  people_id product_id
# 0      005          0       X789
# 1      006          3       X999
# 2      007          2       X789
#   product_id product_desc
# 0       X789        Apple
# 1       X999       Banana
# 2       X990       Orange
#    id     name   age
# 0   0     Paul   NaN
# 1   1  Perrine  67.0
# 2   2   Moussa  24.0
# 3   3   Michel  76.0
# 4   5     Anne  47.0

# %%
# 1 concaténer des lignes

# Concatenate the lines of df_sales2 after df_sales1 :
df_sales = pd.concat([df_sales1,df_sales2], ignore_index=True)
display(df_sales)
# Out:
#   sales_id  people_id product_id
# 0      001          1       X789
# 1      002          4       X999
# 2      003          2       X789
# 3      004          1       X990
# 4      005          0       X789
# 5      006          3       X999
# 6      007          2       X789

# %%
# 2 join columns

# Join columns from sales and product
# Simple case: All product_id in df_sales are present in df_product and vice versa

df_sales_product = df_sales.merge(df_products,on='product_id')   # par défaut c'est un inner join
display(df_sales_product)
# Out:
#   sales_id  people_id product_id product_desc
# 0      001          1       X789        Apple
# 1      003          2       X789        Apple
# 2      005          0       X789        Apple
# 3      007          2       X789        Apple
# 4      002          4       X999       Banana
# 5      006          3       X999       Banana
# 6      004          1       X990       Orange

# %%
# Join columns from people with sales_product
# Warning 1: the columns containing the join id do not have the same name
# Warning 2: the people_id 4 present in df_sales_product does not exist in df_people!
# People_id 5 is in df_people but not in df_sales_product
# We have to make a choice: what to do with the missing ids?

# Inner join: we only keep the ids that are in both tables (default)
df_final1 = df_sales_product.merge(df_people, left_on='people_id', right_on='id', how='inner')

# Outer join: we keep all the ids we find in both tables and fill the missing values in with NaN
df_final2 = df_sales_product.merge(df_people, left_on='people_id', right_on='id', how='outer')

# Left join: we keep all the ids from the left table and fill the mising values with NaN
df_final3 = df_sales_product.merge(df_people, left_on='people_id', right_on='id', how='left')

# Right join: we keep all the ids from the right table and fill the mising values with NaN
df_final4 = df_sales_product.merge(df_people, left_on='people_id', right_on='id', how='right')

# %%
# inner join (ramène moins de valeurs)
display(df_final1)
# Out:
#   sales_id  people_id product_id product_desc  id     name   age
# 0      001          1       X789        Apple   1  Perrine  67.0
# 1      004          1       X990       Orange   1  Perrine  67.0
# 2      003          2       X789        Apple   2   Moussa  24.0
# 3      007          2       X789        Apple   2   Moussa  24.0
# 4      005          0       X789        Apple   0     Paul   NaN
# 5      006          3       X999       Banana   3   Michel  76.0

# %%
# outer join  (crée des valeurs manquantes mais donne plus de valeurs que inner join)
display(df_final2)
# Out:
#   sales_id  people_id product_id product_desc   id     name   age
# 0      001        1.0       X789        Apple  1.0  Perrine  67.0
# 1      004        1.0       X990       Orange  1.0  Perrine  67.0
# 2      003        2.0       X789        Apple  2.0   Moussa  24.0
# 3      007        2.0       X789        Apple  2.0   Moussa  24.0
# 4      005        0.0       X789        Apple  0.0     Paul   NaN
# 5      002        4.0       X999       Banana  NaN      NaN   NaN
# 6      006        3.0       X999       Banana  3.0   Michel  76.0
# 7      NaN        NaN        NaN          NaN  5.0     Anne  47.0

# %%
# left join
display(df_final3)
# Out:
#   sales_id  people_id product_id product_desc   id     name   age
# 0      001          1       X789        Apple  1.0  Perrine  67.0
# 1      003          2       X789        Apple  2.0   Moussa  24.0
# 2      005          0       X789        Apple  0.0     Paul   NaN
# 3      007          2       X789        Apple  2.0   Moussa  24.0
# 4      002          4       X999       Banana  NaN      NaN   NaN
# 5      006          3       X999       Banana  3.0   Michel  76.0
# 6      004          1       X990       Orange  1.0  Perrine  67.0

# %%
# right join
display(df_final4)
# Out:
#   sales_id  people_id product_id product_desc  id     name   age
# 0      005        0.0       X789        Apple   0     Paul   NaN
# 1      001        1.0       X789        Apple   1  Perrine  67.0
# 2      004        1.0       X990       Orange   1  Perrine  67.0
# 3      003        2.0       X789        Apple   2   Moussa  24.0
# 4      007        2.0       X789        Apple   2   Moussa  24.0
# 5      006        3.0       X999       Banana   3   Michel  76.0
# 6      NaN        NaN        NaN          NaN   5     Anne  47.0
